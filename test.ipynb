# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad("results/debug2/data/preprocessed/neftel_smartseq2_brain.h5ad")

# %%
adata[adata.obs["phase"]=="G1"].obs[["sample"]].value_counts()
# Out:
# sample
# MGH105    351
# MGH66     323
# BT771     264
# BT920     243
# MGH125    215
# MGH121    212
# MGH110    209
# BT830     208
# MGH104    207
# BT749     201
# MGH124    198
# MGH143    196
# BT1160    193
# MGH102    174
# MGH129    171
# MGH113    162
# MGH136    153
# BT85      143
# BT786     141
# MGH115    140
# MGH152    136
# MGH100    131
# MGH106    124
# MGH101    120
# MGH122    114
# MGH151     92
# Name: count, dtype: int64

# %%
labels = pd.read_csv("labels/neftel_ss2.csv", index_col=0)

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad("integration/debug/data/preprocessed/ji_skin_all_0.h5ad")

# %%
(adata.var["highly_variable_4000_True"].values == adata.var["highly_variable_4000_False"].values).sum()
# Out:
# np.int64(15730)

# %%
adata.var["highly_variable_4000_True"].values == adata.var["highly_variable_4000_False"].values
# Out:
# array([ True,  True,  True, ...,  True,  True,  True], shape=(18394,))

# %%
adata.obs
# Out:
#            sample  cell_type  complexity technology  n_cells patient  \
# cell_name
# 102_1         102  Malignant        3101        10x     1822     102
# 102_2         102  Malignant        2366        10x     1822     102
# 102_4         102  Malignant        1217        10x     1822     102
# 102_5         102  Malignant        2285        10x     1822     102
# 102_7         102  Malignant        1725        10x     1822     102
# ...           ...        ...         ...        ...      ...     ...
# 105_D2_211    105                    451        10x     4127     105
# 105_D2_212    105  Malignant         506        10x     4127     105
# 105_D2_213    105                    680        10x     4127     105
# 105_D2_214    105  Malignant         622        10x     4127     105
# 105_D2_216    105  Malignant         616        10x     4127     105
#
#              cancer_type sex age  smoking_status  ...  targeted_rx_response  \
# ...
